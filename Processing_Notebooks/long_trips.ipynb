# %% [markdown]
# ### Create 4 Output CSV Files that has all 4 types of anomalies

# %%
import json
import pandas as pd

# Load the data
file_path = 'fixed_traj_new.json'

# Read the JSON lines into a DataFrame
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Filter and write the CSV files
# 1. Time elapsed < 5 minutes
time_less_5 = df[df['time'] < 5 * 60][['trip_id', 'time']]
time_less_5.to_csv('mnt/data/time_less_5.csv', index=False)

# 2. Time elapsed > 60 minutes
time_more_60 = df[df['time'] > 60 * 60][['trip_id', 'time']]
time_more_60.to_csv('mnt/data/time_more_60.csv', index=False)

# 3. Distance travelled < 1 km
dist_less_1 = df[df['dist'] < 1][['trip_id', 'dist']]
dist_less_1.to_csv('mnt/data/dist_less_1.csv', index=False)

# 4. Distance travelled > 50 km
dist_more_50 = df[df['dist'] > 50][['trip_id', 'dist']]
dist_more_50.to_csv('mnt/data/dist_more_50.csv', index=False)

print("CSV files have been created successfully.")
# Out:
# CSV files have been created successfully.

# %% [markdown]
# ### Create an HTML Map File

# %%
import json
import pandas as pd
import folium

# Load the data
file_path = 'fixed_traj_new.json'

# Read the JSON lines into a DataFrame
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Initialize a folium map
m = folium.Map(location=[31.5, 35.5], zoom_start=10)

# Add trip data to the map
for _, row in df.iterrows():
    trip_id = row['trip_id']
    lats = row['lats']
    lngs = row['lngs']
    points = list(zip(lats, lngs))
    folium.PolyLine(points, color="blue", weight=2.5, opacity=1).add_to(m)
    folium.Marker(location=points[0], popup=f'Start: {trip_id}', icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(location=points[-1], popup=f'End: {trip_id}', icon=folium.Icon(color='red')).add_to(m)

# Display the map
m.save('mnt/data/trips_map.html')

# %%
import json
import pandas as pd
import folium

# Load the data
file_path = 'fixed_traj_new.json'

# Read the JSON lines into a DataFrame
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Filter trips with distance greater than 50 km
df_filtered = df[df['dist'] > 50]

# Initialize a folium map
m = folium.Map(location=[31.5, 35.5], zoom_start=10)

# Add filtered trip data to the map
for _, row in df_filtered.iterrows():
    trip_id = row['trip_id']
    lats = row['lats']
    lngs = row['lngs']
    points = list(zip(lats, lngs))
    folium.PolyLine(points, color="blue", weight=2.5, opacity=1).add_to(m)
    folium.Marker(location=points[0], popup=f'Start: {trip_id}', icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(location=points[-1], popup=f'End: {trip_id}', icon=folium.Icon(color='red')).add_to(m)

# Display the map
m.save('mnt/data/trips_map_more_50km.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e2e8a7d3dae1a8b8f959bf45548549b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e2e8a7d3dae1a8b8f959bf45548549b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e2e8a7d3dae1a8b8f959bf45548549b = L.map(
#                 &quot;map_2e2e8a7d3dae1a8b8f959bf45548549b&quot;,
#                 {
#                     center: [31.5, 35.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8629b64150c4e742bf94545dc6f95cdb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8629b64150c4e742bf94545dc6f95cdb.addTo(map_2e2e8a7d3dae1a8b8f959bf45548549b);
#
#
#             var poly_line_93e99c569a205ba749312f946ba091c5 = L.polyline(
#                 [[31.975, 35.848], [31.976, 35.85], [31.976, 35.85], [31.976, 35.85], [31.975, 35.851], [31.975, 35.851], [31.974, 35.848], [31.974, 35.848], [31.974, 35.847], [31.974, 35.846], [31.974, 35.845], [31.974, 35.845], [31.974, 35.844], [31.974, 35.843], [31.973, 35.843], [31.973, 35.842], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.972, 35.841], [31.972, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.84], [31.972, 35.84], [31.973, 35.84], [31.974, 35.839], [31.975, 35.839], [31.981, 35.835], [31.981, 35.835], [31.982, 35.834], [31.983, 35.834], [31.983, 35.833], [31.983, 35.833], [31.982, 35.832], [31.982, 35.832], [31.981, 35.831], [31.981, 35.83], [31.981, 35.829], [31.981, 35.829], [31.981, 35.828], [31.98, 35.826], [31.98, 35.826], [31.98, 35.825], [31.98, 35.824], [31.98, 35.823], [31.98, 35.822], [31.981, 35.822], [31.981, 35.822], [31.982, 35.822], [31.987, 35.82], [31.987, 35.82], [31.988, 35.82], [31.989, 35.819], [31.988, 35.819], [31.988, 35.819], [31.988, 35.818], [31.988, 35.818], [31.988, 35.818], [31.988, 35.817], [31.988, 35.817], [31.989, 35.817], [31.989, 35.817], [31.989, 35.817], [31.99, 35.817], [31.99, 35.816], [31.991, 35.815], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_2e2e8a7d3dae1a8b8f959bf45548549b);
#
#
#             var marker_e3086a7505ca18d0f821e9b598410132 = L.marker(
#                 [31.975, 35.848],
#                 {}
#             ).addTo(map_2e2e8a7d3dae1a8b8f959bf45548549b);
#
#
#             var icon_ad0228159c63847c28540bad3580208d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e3086a7505ca18d0f821e9b598410132.setIcon(icon_ad0228159c63847c28540bad3580208d);
#
#
#         var popup_ad71db31851b5ffd15cc7f46131ce3ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5b8a7beb5f5de7f173f081119c79176 = $(`&lt;div id=&quot;html_d5b8a7beb5f5de7f173f081119c79176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start: 077338a20e9485eea573bf921428ad85f207090f55a9ac3e1c531903f2621c0f&lt;/div&gt;`)[0];
#                 popup_ad71db31851b5ffd15cc7f46131ce3ab.setContent(html_d5b8a7beb5f5de7f173f081119c7917

# %%
import json
import pandas as pd
import folium
import matplotlib.pyplot as plt
import numpy as np

# Load the data
file_path = 'fixed_traj_new.json'

# Read the JSON lines into a DataFrame
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Filter trips with distance greater than 50 km
df_filtered = df[df['dist'] > 50]

# Initialize a folium map
m = folium.Map(location=[31.5, 35.5], zoom_start=10)

# Generate a colormap
num_trips = len(df_filtered)
colors = plt.cm.rainbow(np.linspace(0, 1, num_trips))

# Add filtered trip data to the map with unique colors
for i, (_, row) in enumerate(df_filtered.iterrows()):
    trip_id = row['trip_id']
    lats = row['lats']
    lngs = row['lngs']
    points = list(zip(lats, lngs))
    color = f'#{int(colors[i][0]*255):02x}{int(colors[i][1]*255):02x}{int(colors[i][2]*255):02x}'
    folium.PolyLine(points, color=color, weight=2.5, opacity=1).add_to(m)
    folium.Marker(location=points[0], popup=f'Start: {trip_id}', icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(location=points[-1], popup=f'End: {trip_id}', icon=folium.Icon(color='red')).add_to(m)

# Save and display the map
m.save('mnt/data/trips_map_more_50km_color_coded.html')
m
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1565af5992dfaa26269f97d0970be6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1565af5992dfaa26269f97d0970be6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1565af5992dfaa26269f97d0970be6b = L.map(
#                 &quot;map_d1565af5992dfaa26269f97d0970be6b&quot;,
#                 {
#                     center: [31.5, 35.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5118ec19f97ef3f81f284673e062e20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c5118ec19f97ef3f81f284673e062e20.addTo(map_d1565af5992dfaa26269f97d0970be6b);
#
#
#             var poly_line_8933e509ec9e29d1b1980b60a0efe2ae = L.polyline(
#                 [[31.975, 35.848], [31.976, 35.85], [31.976, 35.85], [31.976, 35.85], [31.975, 35.851], [31.975, 35.851], [31.974, 35.848], [31.974, 35.848], [31.974, 35.847], [31.974, 35.846], [31.974, 35.845], [31.974, 35.845], [31.974, 35.844], [31.974, 35.843], [31.973, 35.843], [31.973, 35.842], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.972, 35.841], [31.972, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.84], [31.972, 35.84], [31.973, 35.84], [31.974, 35.839], [31.975, 35.839], [31.981, 35.835], [31.981, 35.835], [31.982, 35.834], [31.983, 35.834], [31.983, 35.833], [31.983, 35.833], [31.982, 35.832], [31.982, 35.832], [31.981, 35.831], [31.981, 35.83], [31.981, 35.829], [31.981, 35.829], [31.981, 35.828], [31.98, 35.826], [31.98, 35.826], [31.98, 35.825], [31.98, 35.824], [31.98, 35.823], [31.98, 35.822], [31.981, 35.822], [31.981, 35.822], [31.982, 35.822], [31.987, 35.82], [31.987, 35.82], [31.988, 35.82], [31.989, 35.819], [31.988, 35.819], [31.988, 35.819], [31.988, 35.818], [31.988, 35.818], [31.988, 35.818], [31.988, 35.817], [31.988, 35.817], [31.989, 35.817], [31.989, 35.817], [31.989, 35.817], [31.99, 35.817], [31.99, 35.816], [31.991, 35.815], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#7f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d1565af5992dfaa26269f97d0970be6b);
#
#
#             var marker_fabd512b6753987a8318a79d324ff6f8 = L.marker(
#                 [31.975, 35.848],
#                 {}
#             ).addTo(map_d1565af5992dfaa26269f97d0970be6b);
#
#
#             var icon_6db6d8cd3f0798c9ee8387e23c4389ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fabd512b6753987a8318a79d324ff6f8.setIcon(icon_6db6d8cd3f0798c9ee8387e23c4389ed);
#
#
#         var popup_836adbda8b49a736cf07ca1f88859aa2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdb8864710627167ab8c4afbb280c5a3 = $(`&lt;div id=&quot;html_cdb8864710627167ab8c4afbb280c5a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start: 077338a20e9485eea573bf921428ad85f207090f55a9ac3e1c531903f2621c0f&lt;/div&gt;`)[0];
#                 popup_836adbda8b49a736cf07ca1f88859aa2.setContent(html_cdb8864710627167ab8c4afbb

# %%
import json
import pandas as pd
import folium

# Load the data
file_path = 'fixed_traj_new.json'

# Read the JSON lines into a DataFrame
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Filter trips with distance greater than 50 km
df_filtered = df[df['dist'] > 50]

# Initialize a folium map
m = folium.Map(location=[31.5, 35.5], zoom_start=10)

# Add filtered trip data to the map with tooltips
for _, row in df_filtered.iterrows():
    trip_id = row['trip_id']
    lats = row['lats']
    lngs = row['lngs']
    points = list(zip(lats, lngs))
    folium.PolyLine(points, color="blue", weight=2.5, opacity=1, tooltip=f'Trip ID: {trip_id}').add_to(m)
    folium.Marker(location=points[0], popup=f'Start: {trip_id}', icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(location=points[-1], popup=f'End: {trip_id}', icon=folium.Icon(color='red')).add_to(m)

# Save and display the map
m.save('mnt/data/trips_map_more_50km_tooltip.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04938f33d8ccbe106d5d170b54b7d15e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04938f33d8ccbe106d5d170b54b7d15e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04938f33d8ccbe106d5d170b54b7d15e = L.map(
#                 &quot;map_04938f33d8ccbe106d5d170b54b7d15e&quot;,
#                 {
#                     center: [31.5, 35.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f92d8e59d45af1e1e7eaa54b8c96d61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2f92d8e59d45af1e1e7eaa54b8c96d61.addTo(map_04938f33d8ccbe106d5d170b54b7d15e);
#
#
#             var poly_line_385615166bcda09289152523f3245965 = L.polyline(
#                 [[31.975, 35.848], [31.976, 35.85], [31.976, 35.85], [31.976, 35.85], [31.975, 35.851], [31.975, 35.851], [31.974, 35.848], [31.974, 35.848], [31.974, 35.847], [31.974, 35.846], [31.974, 35.845], [31.974, 35.845], [31.974, 35.844], [31.974, 35.843], [31.973, 35.843], [31.973, 35.842], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [30.084, 31.352], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.973, 35.841], [31.972, 35.841], [31.972, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.841], [31.971, 35.84], [31.972, 35.84], [31.973, 35.84], [31.974, 35.839], [31.975, 35.839], [31.981, 35.835], [31.981, 35.835], [31.982, 35.834], [31.983, 35.834], [31.983, 35.833], [31.983, 35.833], [31.982, 35.832], [31.982, 35.832], [31.981, 35.831], [31.981, 35.83], [31.981, 35.829], [31.981, 35.829], [31.981, 35.828], [31.98, 35.826], [31.98, 35.826], [31.98, 35.825], [31.98, 35.824], [31.98, 35.823], [31.98, 35.822], [31.981, 35.822], [31.981, 35.822], [31.982, 35.822], [31.987, 35.82], [31.987, 35.82], [31.988, 35.82], [31.989, 35.819], [31.988, 35.819], [31.988, 35.819], [31.988, 35.818], [31.988, 35.818], [31.988, 35.818], [31.988, 35.817], [31.988, 35.817], [31.989, 35.817], [31.989, 35.817], [31.989, 35.817], [31.99, 35.817], [31.99, 35.816], [31.991, 35.815], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814], [31.991, 35.814]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_04938f33d8ccbe106d5d170b54b7d15e);
#
#
#             poly_line_385615166bcda09289152523f3245965.bindTooltip(
#                 `&lt;div&gt;
#                      Trip ID: 077338a20e9485eea573bf921428ad85f207090f55a9ac3e1c531903f2621c0f
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61efdaae89757e4ee48bfebdc42b7888 = L.marker(
#                 [31.975, 35.848],
#                 {}
#             ).addTo(map_04938f33d8ccbe106d5d170b54b7d15e);
#
#
#             var icon_b2dcde256f55ac06a063513555ca461d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61efdaae89757e4ee48bfebdc42b7888.setIcon(icon_b2dcde256f55ac06a063513555ca461d);
#
#
#         var popup_722a860321cb262c7b1a6160e5cc9a01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8699470ad128235aa9c37e9ec1ff5391 = $(`&lt;div i
